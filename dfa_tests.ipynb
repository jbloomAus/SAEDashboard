# %% [markdown]
# # Demo Notebook

# %% [markdown]
# Steps:
# 1. Download SAE with SAE Lens.
# 2. Create a dataset consistent with that SAE.
# 3. Fold the SAE decoder norm weights so that feature activations are "correct".
# 4. Estimate the activation normalization constant if needed, and fold it into the SAE weights.
# 5. Run the SAE generator for the features you want.

# %% [markdown]
# # Set Up

# %%
import torch
from sae_lens import SAE 
from transformer_lens import HookedTransformer
from sae_dashboard.sae_vis_data import SaeVisConfig
from sae_dashboard.sae_vis_runner import SaeVisRunner
from huggingface_hub import notebook_login

# %%
# notebook_login()

# %% [markdown]
# ## Step 1. Download / Initialize SAE

# %%
# For the most part I'll try to import functions and classes near where they are used
# to make it clear where they come from.

if torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Device: {device}")

model = HookedTransformer.from_pretrained("gpt2", device = device)

# the cfg dict is returned alongside the SAE since it may contain useful information for analysing the SAE (eg: instantiating an activation store)
# Note that this is not the same as the SAEs config dict, rather it is whatever was in the HF repo, from which we can extract the SAE config dict
# We also return the feature sparsities which are stored in HF for convenience. 
sae, _, _ = SAE.from_pretrained(
        release="gpt2-small-hook-z-kk",
        sae_id="blocks.5.hook_z",
        device=device
    )
# fold w_dec norm so feature activations are accurate
sae.fold_W_dec_norm()
# Out:
# Device: cuda
# /root/.cache/pypoetry/virtualenvs/sae-dashboard-EXnyewPT-py3.10/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded pretrained model gpt2 into HookedTransformer
# /root/.cache/pypoetry/virtualenvs/sae-dashboard-EXnyewPT-py3.10/lib/python3.10/site-packages/sae_lens/toolkit/pretrained_sae_loaders.py:147: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   weights = torch.load(file_path, map_location=device)

# %% [markdown]
# # 2. Get token dataset

# %%
from sae_lens import ActivationsStore

activations_store = ActivationsStore.from_sae(
    model = model,
    sae = sae,
    streaming=True,
    store_batch_size_prompts=16,
    n_batches_in_buffer=8,
    device=device
)

# Some SAEs will require we estimate the activation norm and fold it into the weights. This is easy with SAE Lens. 
if sae.cfg.normalize_activations == "expected_average_only_in":
    norm_scaling_factor = activations_store.estimate_norm_scaling_factor(n_batches_for_norm_estimate=30)
    sae.fold_activation_norm_scaling_factor(norm_scaling_factor)
# Out:
# Warning: Dataset is not tokenized. Pre-tokenizing will improve performance and allows for more control over special tokens. See https://jbloomaus.github.io/SAELens/training_saes/#pretokenizing-datasets for more info.

# %%
from tqdm import tqdm 

def get_tokens(
    activations_store: ActivationsStore,
    n_prompts: int,
):
    all_tokens_list = []
    pbar = tqdm(range(n_prompts))
    for _ in pbar:
        batch_tokens = activations_store.get_batch_tokens()
        batch_tokens = batch_tokens[torch.randperm(batch_tokens.shape[0])][
            : batch_tokens.shape[0]
        ]
        all_tokens_list.append(batch_tokens)

    all_tokens = torch.cat(all_tokens_list, dim=0)
    all_tokens = all_tokens[torch.randperm(all_tokens.shape[0])]
    return all_tokens

# 1000 prompts is plenty for a demo.
token_dataset = get_tokens(activations_store, 256)
print(f"Token dataset size: {token_dataset.shape}")
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1217 > 1024). Running this sequence through the model will result in indexing errors
# 100%|██████████| 256/256 [00:02<00:00, 120.11it/s]
# Token dataset size: torch.Size([4096, 128])

# %%
insert = model.to_tokens("Stalinists shriek in the ears of the police that")
token_dataset[0, :13] = insert[0]

# %% [markdown]
# # 4. Generate Feature Dashboards

# %%
import gc 
gc.collect()
torch.cuda.empty_cache()

# %%
from pathlib import Path
test_feature_idx_gpt = list(range(64))

feature_vis_config_gpt = SaeVisConfig(
    hook_point=sae.cfg.hook_name,
    features=test_feature_idx_gpt,
    minibatch_size_features=32,
    minibatch_size_tokens=256, # this is number of prompts at a time.
    verbose=True,
    device="cuda",
    #cache_dir=Path("demo_activations_cache"), # this will enable us to skip running the model for subsequent features.
    dtype="bfloat16",
    use_dfa=True,
)

data = SaeVisRunner(feature_vis_config_gpt).run(
    encoder=sae, # type: ignore
    model=model,
    tokens=token_dataset,
)
# Out:
# Forward passes to cache data for vis:   0%|          | 0/32 [00:00<?, ?it/s]
# Extracting vis data from cached data:   0%|          | 0/64 [00:00<?, ?it/s]
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# shape of feat_acts: torch.Size([4096, 128])
# ┏━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Task ┃ Time ┃ Pct % ┃
# ┡━━━━━━╇━━━━━━╇━━━━━━━┩
# └──────┴──────┴───────┘

# %%
type(data.feature_data_dict[0].dfa_data[0])
# Out:
# dict

# %%
type(data.feature_data_dict[0].dfa_data[0]["dfaValues"][0])
# Out:
# float

# %% [markdown]
# ## Test Neuronpedia Runner

# %%
import os

from sae_dashboard.neuronpedia.neuronpedia_runner import (
    NeuronpediaRunner,
    NeuronpediaRunnerConfig,
)

# python neuronpedia.py generate --sae-set=res-jb --sae-path=/opt/Gemma-2b-Residual-Stream-SAEs/gemma_2b_blocks.10.hook_resid_post_16384 --dataset-path=Skylion007/openwebtext --log-sparsity=-6 --dtype= --feat-per-batch=128 --n-prompts=24576 --n-context-tokens=128 --n-prompts-in-forward-pass=128 --resume-from-batch=0 --end-at-batch=-1

# LOCAL PATHS
NP_OUTPUT_FOLDER = "neuronpedia_outputs/"
ACT_CACHE_FOLDER = "cached_activations"

# NP SET NAME
NP_SET_NAME = "att-kk"
SAE_SET = "gpt2-small-hook-z-kk"
SAE_PATH = "blocks.5.hook_z"

# DATAEST
HF_DATASET_PATH = "Skylion007/openwebtext"


SPARSITY_THRESHOLD = 1

# IMPORTANT
SAE_DTYPE = "float32"
MODEL_DTYPE = "float32"

# PERFORMANCE SETTING
N_PROMPTS = 256
N_TOKENS_IN_PROMPT = 128
N_PROMPTS_IN_FORWARD_PASS = 128
NUM_FEATURES_PER_BATCH = 256

# %%
# delete output files if present
os.system(f"rm -rf {NP_OUTPUT_FOLDER}")
os.system(f"rm -rf {ACT_CACHE_FOLDER}")

# # we make two batches of 2 features each
cfg = NeuronpediaRunnerConfig(
    sae_set=SAE_SET,
    sae_path=SAE_PATH,
    np_set_name=NP_SET_NAME,
    from_local_sae=False,
    huggingface_dataset_path=HF_DATASET_PATH,
    sae_dtype=SAE_DTYPE,
    model_dtype=MODEL_DTYPE,
    outputs_dir=NP_OUTPUT_FOLDER,
    sparsity_threshold=SPARSITY_THRESHOLD,
    n_prompts_total=N_PROMPTS,
    n_tokens_in_prompt=N_TOKENS_IN_PROMPT,
    n_prompts_in_forward_pass=N_PROMPTS_IN_FORWARD_PASS,
    n_features_at_a_time=NUM_FEATURES_PER_BATCH,
    start_batch=0,
    end_batch=0,
    use_dfa=True,
    use_wandb=False,
    # TESTING ONLY
    # end_batch=6,
)

runner = NeuronpediaRunner(cfg)
runner.run()
# Out:
# /root/.cache/pypoetry/virtualenvs/sae-dashboard-EXnyewPT-py3.10/lib/python3.10/site-packages/sae_lens/toolkit/pretrained_sae_loaders.py:147: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   weights = torch.load(file_path, map_location=device)
# Overriding sae dtype to float32
# Device Count: 1
# SAE Device: cuda
# Model Device: cuda
# Model Num Devices: None
# Activation Store Device: cuda
# Dataset Path: Skylion007/openwebtext
# Forward Pass size: 128
# Total number of tokens: 32768
# Total number of contexts (prompts): 256
# SAE Config on disk:
# {
#   "architecture": "standard",
#   "d_in": 768,
#   "d_sae": 49152,
#   "dtype": "torch.float32",
#   "device": "cuda",
#   "model_name": "gpt2-small",
#   "hook_name": "blocks.5.attn.hook_z",
#   "hook_layer": 5,
#   "hook_head_index": null,
#   "activation_fn_str": "relu",
#   "activation_fn_kwargs": {},
#   "apply_b_dec_to_input": true,
#   "finetuning_scaling_factor": false,
#   "sae_lens_training_version": null,
#   "prepend_bos": true,
#   "dataset_path": "Skylion007/openwebtext",
#   "dataset_trust_remote_code": true,
#   "context_size": 128,
#   "normalize_activations": "none"
# }
# SAE does not have from_pretrained_kwargs. Standard TransformerLens Loading
# SAE DType: float32
# Model DType: float32
# /root/.cache/pypoetry/virtualenvs/sae-dashboard-EXnyewPT-py3.10/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded pretrained model gpt2-small into HookedTransformer
# Warning: Dataset is not tokenized. Pre-tokenizing will improve performance and allows for more control over special tokens. See https://jbloomaus.github.io/SAELens/training_saes/#pretokenizing-datasets for more info.
# Skipping sparsity because sparsity_threshold was set to 1
# Tokens don't exist, making them.
#   0%|          | 0/32 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1217 > 1024). Running this sequence through the model will result in indexing errors
# 100%|██████████| 32/32 [00:00<00:00, 129.83it/s]
# 0it [00:00, ?it/s]
# ========== Running Batch #0 ==========
# DFA flag set to True
# Forward passes to cache data for vis:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting vis data from cached data:   0%|          | 0/256 [00:00<?, ?it/s]
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         30942,  6599, 23186, 28453, 20722])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[241,  94],
#         [ 51,  71],
#         [181,  18],
#         [222,  37],
#         [161, 114]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          5272, 20975, 32065,  7147, 19755])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 41,  24],
#         [163, 111],
#         [250,  65],
#         [ 55, 107],
#         [154,  43]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          9800,  2532,  5259, 25643, 18063])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 76,  72],
#         [ 19, 100],
#         [ 41,  11],
#         [200,  43],
#         [141,  15]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         21793, 27926,  4075,  6593,  9591])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[170,  33],
#         [218,  22],
#         [ 31, 107],
#         [ 51,  65],
#         [ 74, 119]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         27893,  6651, 17034,  4587, 14472])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[217, 117],
#         [ 51, 123],
#         [133,  10],
#         [ 35, 107],
#         [113,   8]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         16429,  7681, 28987, 11456,   865])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[128,  45],
#         [ 60,   1],
#         [226,  59],
#         [ 89,  64],
#         [  6,  97]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([ 3269, 27924,  8077, 27923,    15,    14,    12,    13,     9,     8,
#            10,    11,     3,     2,     0,     1,     7,     6,     4,     5,
#          3269,  8077, 27923, 27924, 15456, 22326, 13433, 29498, 18650])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.455': tensor([[ 25,  69],
#         [218,  20],
#         [ 63,  13],
#         [218,  19],
#         [  0,  15],
#         [  0,  14],
#         [  0,  12],
#         [  0,  13],
#         [  0,   9],
#         [  0,   8],
#         [  0,  10],
#         [  0,  11],
#         [  0,   3],
#         [  0,   2],
#         [  0,   0],
#         [  0,   1],
#         [  0,   7],
#         [  0,   6],
#         [  0,   4],
#         [  0,   5]]), 'INTERVAL 0.364 - 0.455<br>CONTAINS 0.003%': tensor([[25, 69]]), 'INTERVAL 0.273 - 0.364<br>CONTAINS 0.009%': tensor([[ 63,  13],
#         [218,  19],
#         [218,  20]]), 'INTERVAL 0.182 - 0.273<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.091 - 0.182<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.000 - 0.091<br>CONTAINS 99.988%': tensor([[120,  96],
#         [174,  54],
#         [104, 121],
#         [230,  58],
#         [145,  90]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         27159,  5290,    99, 12603, 21915])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[212,  23],
#         [ 41,  42],
#         [  0,  99],
#         [ 98,  59],
#         [171,  27]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         21361, 20451, 30598,  3267, 27206])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[166, 113],
#         [159,  99],
#         [239,   6],
#         [ 25,  67],
#         [212,  70]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         25997,  5331,  1431, 18003, 29686])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[203,  13],
#         [ 41,  83],
#         [ 11,  23],
#         [140,  83],
#         [231, 118]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         13621, 24613, 19073,   583,  9073])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[106,  53],
#         [192,  37],
#         [149,   1],
#         [  4,  71],
#         [ 70, 113]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          3162, 20177, 11769,  4644, 19835])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 24,  90],
#         [157,  81],
#         [ 91, 121],
#         [ 36,  36],
#         [154, 123]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         24613,  5696,  4314,  5548, 12978])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[192,  37],
#         [ 44,  64],
#         [ 33,  90],
#         [ 43,  44],
#         [101,  50]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([24200, 27414, 10657, 28732,    15,    14,    12,    13,     9,     8,
#            10,    11,     3,     2,     0,     1,     7,     6,     4,     5,
#         24200, 10657, 27414, 24573,  7243,  2003, 12610,   257])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.515': tensor([[189,   8],
#         [214,  22],
#         [ 83,  33],
#         [224,  60],
#         [  0,  15],
#         [  0,  14],
#         [  0,  12],
#         [  0,  13],
#         [  0,   9],
#         [  0,   8],
#         [  0,  10],
#         [  0,  11],
#         [  0,   3],
#         [  0,   2],
#         [  0,   0],
#         [  0,   1],
#         [  0,   7],
#         [  0,   6],
#         [  0,   4],
#         [  0,   5]]), 'INTERVAL 0.412 - 0.515<br>CONTAINS 0.003%': tensor([[189,   8]]), 'INTERVAL 0.309 - 0.412<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.206 - 0.309<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.103 - 0.206<br>CONTAINS 0.006%': tensor([[ 83,  33],
#         [214,  22]]), 'INTERVAL 0.000 - 0.103<br>CONTAINS 99.991%': tensor([[191, 125],
#         [ 56,  75],
#         [ 15,  83],
#         [ 98,  66],
#         [  2,   1]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          7792, 32577, 26080, 16808, 13581])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 60, 112],
#         [254,  65],
#         [203,  96],
#         [131,  40],
#         [106,  13]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([ 8499,  9241,  7666, 28244, 10584, 20755, 20754, 17304,  7665, 17307,
#         17309, 17299, 17308, 20756,  4074,  4963,  2999,  7670, 20757, 28239,
#          8499,  9241,  7666, 10584, 28244,  4074, 20755,  7665, 17308,  4963,
#          7594,  9539, 29549, 22717, 20759, 17940, 27142,  4967,  3435, 32451])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 1.068': tensor([[ 66,  51],
#         [ 72,  25],
#         [ 59, 114],
#         [220,  84],
#         [ 82,  88],
#         [162,  19],
#         [162,  18],
#         [135,  24],
#         [ 59, 113],
#         [135,  27],
#         [135,  29],
#         [135,  19],
#         [135,  28],
#         [162,  20],
#         [ 31, 106],
#         [ 38,  99],
#         [ 23,  55],
#         [ 59, 118],
#         [162,  21],
#         [220,  79]]), 'INTERVAL 0.854 - 1.068<br>CONTAINS 0.006%': tensor([[66, 51],
#         [72, 25]]), 'INTERVAL 0.641 - 0.854<br>CONTAINS 0.009%': tensor([[ 59, 114],
#         [ 82,  88],
#         [220,  84]]), 'INTERVAL 0.427 - 0.641<br>CONTAINS 0.049%': tensor([[ 31, 106],
#         [162,  19],
#         [ 59, 113],
#         [135,  28],
#         [ 38,  99]]), 'INTERVAL 0.214 - 0.427<br>CONTAINS 0.101%': tensor([[ 59,  42],
#         [ 74,  67],
#         [230, 109],
#         [177,  61],
#         [162,  23]]), 'INTERVAL 0.000 - 0.214<br>CONTAINS 99.835%': tensor([[140,  20],
#         [212,   6],
#         [ 38, 103],
#         [ 26, 107],
#         [253,  67]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         30830,  4348,  5547,  2583, 14751])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[240, 110],
#         [ 33, 124],
#         [ 43,  43],
#         [ 20,  23],
#         [115,  31]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         15307,  1342,    15, 11925, 19820])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[119,  75],
#         [ 10,  62],
#         [  0,  15],
#         [ 93,  21],
#         [154, 108]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         32232,  5349,  9920, 23119, 26944])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[251, 104],
#         [ 41, 101],
#         [ 77,  64],
#         [180,  79],
#         [210,  64]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         22142,  8147, 19423,  8330, 25404])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[172, 126],
#         [ 63,  83],
#         [151,  95],
#         [ 65,  10],
#         [198,  60]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([16383, 16357,  3308, 16377, 16378, 16350, 16355, 16358, 16382,  3306,
#         16334, 16352, 16351,  7325, 16356, 16353,  3252,  3301,  3244,  3314,
#         16355,  3308, 16378, 16350,  3306,  7383, 16351,  7380,  3307, 16352,
#         16331, 19833,  3312,  3279, 19742,  7365,  3241, 19784, 26162, 19799,
#         18954, 29011,  7155,  7685,  3063])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 2.053': tensor([[127, 127],
#         [127, 101],
#         [ 25, 108],
#         [127, 121],
#         [127, 122],
#         [127,  94],
#         [127,  99],
#         [127, 102],
#         [127, 126],
#         [ 25, 106],
#         [127,  78],
#         [127,  96],
#         [127,  95],
#         [ 57,  29],
#         [127, 100],
#         [127,  97],
#         [ 25,  52],
#         [ 25, 101],
#         [ 25,  44],
#         [ 25, 114]]), 'INTERVAL 1.642 - 2.053<br>CONTAINS 0.034%': tensor([[127,  99],
#         [ 25, 108],
#         [127, 122],
#         [127,  94],
#         [ 25, 106]]), 'INTERVAL 1.232 - 1.642<br>CONTAINS 0.137%': tensor([[ 57,  87],
#         [127,  95],
#         [ 57,  84],
#         [ 25, 107],
#         [127,  96]]), 'INTERVAL 0.821 - 1.232<br>CONTAINS 0.305%': tensor([[127,  75],
#         [154, 121],
#         [ 25, 112],
#         [ 25,  79],
#         [154,  30]]), 'INTERVAL 0.411 - 0.821<br>CONTAINS 0.598%': tensor([[ 57,  69],
#         [ 25,  41],
#         [154,  72],
#         [204,  50],
#         [154,  87]]), 'INTERVAL 0.000 - 0.411<br>CONTAINS 98.926%': tensor([[148,  10],
#         [226,  83],
#         [ 55, 115],
#         [ 60,   5],
#         [ 23, 119]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([27580, 27577, 27578,    16,     0,    15,    13,    14,    10,     9,
#            11,     6,    12,     3,     1,     2,     8,     7,     5,     4,
#         27580, 27577, 27578, 25439, 26849, 28992, 29126, 20559])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.115': tensor([[215,  60],
#         [215,  57],
#         [215,  58],
#         [  0,  16],
#         [  0,   0],
#         [  0,  15],
#         [  0,  13],
#         [  0,  14],
#         [  0,  10],
#         [  0,   9],
#         [  0,  11],
#         [  0,   6],
#         [  0,  12],
#         [  0,   3],
#         [  0,   1],
#         [  0,   2],
#         [  0,   8],
#         [  0,   7],
#         [  0,   5],
#         [  0,   4]]), 'INTERVAL 0.092 - 0.115<br>CONTAINS 0.003%': tensor([[215,  60]]), 'INTERVAL 0.069 - 0.092<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.046 - 0.069<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.023 - 0.046<br>CONTAINS 0.006%': tensor([[215,  57],
#         [215,  58]]), 'INTERVAL 0.000 - 0.023<br>CONTAINS 99.991%': tensor([[198,  95],
#         [209,  97],
#         [226,  64],
#         [227,  70],
#         [160,  79]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         16553,  5147, 23101,  4609,  7954])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[129,  41],
#         [ 40,  27],
#         [180,  61],
#         [ 36,   1],
#         [ 62,  18]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         12254, 29756,  7365, 31240, 22573])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 95,  94],
#         [232,  60],
#         [ 57,  69],
#         [244,   8],
#         [176,  45]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         15914, 15509, 12054, 19074, 24409])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[124,  42],
#         [121,  21],
#         [ 94,  22],
#         [149,   2],
#         [190,  89]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         24669, 26779,   552, 27343, 21015])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[192,  93],
#         [209,  27],
#         [  4,  40],
#         [213,  79],
#         [164,  23]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          9343, 23289, 30306,  5668, 31672])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 72, 127],
#         [181, 121],
#         [236,  98],
#         [ 44,  36],
#         [247,  56]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         17699,  2657,    16, 16814, 26111])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[138,  35],
#         [ 20,  97],
#         [  0,  16],
#         [131,  46],
#         [203, 127]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          8809, 13780,  6901, 26922, 26438])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 68, 105],
#         [107,  84],
#         [ 53, 117],
#         [210,  42],
#         [206,  70]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         32290,  3946, 29096, 19672,  9359])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[252,  34],
#         [ 30, 106],
#         [227,  40],
#         [153,  88],
#         [ 73,  15]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         18869, 12530,  6911, 28443, 30205])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[147,  53],
#         [ 97, 114],
#         [ 53, 127],
#         [222,  27],
#         [235, 125]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([20269, 20273, 20270, 20274, 29611, 29610, 29612, 20268, 20271, 29608,
#         20272, 29615, 29614,     6,     3,     5,     1,     0,     2,     4,
#         20269, 20273, 20270, 20274, 29610, 29611, 20268, 20271, 29612, 23479,
#         10819, 12587,  5513, 10836])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 3.667': tensor([[158,  45],
#         [158,  49],
#         [158,  46],
#         [158,  50],
#         [231,  43],
#         [231,  42],
#         [231,  44],
#         [158,  44],
#         [158,  47],
#         [231,  40],
#         [158,  48],
#         [231,  47],
#         [231,  46],
#         [  0,   6],
#         [  0,   3],
#         [  0,   5],
#         [  0,   1],
#         [  0,   0],
#         [  0,   2],
#         [  0,   4]]), 'INTERVAL 2.934 - 3.667<br>CONTAINS 0.006%': tensor([[158,  45],
#         [158,  49]]), 'INTERVAL 2.200 - 2.934<br>CONTAINS 0.006%': tensor([[158,  46],
#         [158,  50]]), 'INTERVAL 1.467 - 2.200<br>CONTAINS 0.006%': tensor([[231,  42],
#         [231,  43]]), 'INTERVAL 0.733 - 1.467<br>CONTAINS 0.009%': tensor([[158,  44],
#         [158,  47],
#         [231,  44]]), 'INTERVAL 0.000 - 0.733<br>CONTAINS 99.973%': tensor([[183,  55],
#         [ 84,  67],
#         [ 98,  43],
#         [ 43,   9],
#         [ 84,  84]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([26016, 16370, 16371, 17038,  8274,    14,    11,    13,     9,     7,
#            10,    12,     8,     2,     0,     1,     6,     5,     3,     4,
#         26016, 16370, 16371, 17038, 13818, 21236, 29403, 22530, 14262])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.646': tensor([[203,  32],
#         [127, 114],
#         [127, 115],
#         [133,  14],
#         [ 64,  82],
#         [  0,  14],
#         [  0,  11],
#         [  0,  13],
#         [  0,   9],
#         [  0,   7],
#         [  0,  10],
#         [  0,  12],
#         [  0,   8],
#         [  0,   2],
#         [  0,   0],
#         [  0,   1],
#         [  0,   6],
#         [  0,   5],
#         [  0,   3],
#         [  0,   4]]), 'INTERVAL 0.517 - 0.646<br>CONTAINS 0.003%': tensor([[203,  32]]), 'INTERVAL 0.388 - 0.517<br>CONTAINS 0.003%': tensor([[127, 114]]), 'INTERVAL 0.258 - 0.388<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.129 - 0.258<br>CONTAINS 0.006%': tensor([[127, 115],
#         [133,  14]]), 'INTERVAL 0.000 - 0.129<br>CONTAINS 99.988%': tensor([[107, 122],
#         [165, 116],
#         [229,  91],
#         [176,   2],
#         [111,  54]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         15337,  5548, 12239, 23829,  3734])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[119, 105],
#         [ 43,  44],
#         [ 95,  79],
#         [186,  21],
#         [ 29,  22]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         10673, 22924,   253, 18992,   467])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 83,  49],
#         [179,  12],
#         [  1, 125],
#         [148,  48],
#         [  3,  83]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          5250, 13735, 22658, 12306, 13213])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 41,   2],
#         [107,  39],
#         [177,   2],
#         [ 96,  18],
#         [103,  29]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          7741,  5610,  5339, 15803,  6470])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 60,  61],
#         [ 43, 106],
#         [ 41,  91],
#         [123,  59],
#         [ 50,  70]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         19440, 28952, 30282, 17104, 17861])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[151, 112],
#         [226,  24],
#         [236,  74],
#         [133,  80],
#         [139,  69]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([17647,  1493, 17657,  9781, 17656,  1494, 14077, 14775, 22876, 22877,
#          1499, 27443, 14740,  1498, 14781,  9779, 31856, 25644,  9782, 22880,
#          1493, 17647,  9781, 17656, 17657,  1499,  1494, 22876, 14077, 14775,
#          9782, 25644,  9779, 27443, 31856, 28847, 24136, 32694, 21628,   211])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.376': tensor([[137, 111],
#         [ 11,  85],
#         [137, 121],
#         [ 76,  53],
#         [137, 120],
#         [ 11,  86],
#         [109, 125],
#         [115,  55],
#         [178,  92],
#         [178,  93],
#         [ 11,  91],
#         [214,  51],
#         [115,  20],
#         [ 11,  90],
#         [115,  61],
#         [ 76,  51],
#         [248, 112],
#         [200,  44],
#         [ 76,  54],
#         [178,  96]]), 'INTERVAL 0.301 - 0.376<br>CONTAINS 0.006%': tensor([[ 11,  85],
#         [137, 111]]), 'INTERVAL 0.226 - 0.301<br>CONTAINS 0.009%': tensor([[ 76,  53],
#         [137, 120],
#         [137, 121]]), 'INTERVAL 0.150 - 0.226<br>CONTAINS 0.018%': tensor([[ 11,  91],
#         [ 11,  86],
#         [178,  92],
#         [109, 125],
#         [115,  55]]), 'INTERVAL 0.075 - 0.150<br>CONTAINS 0.027%': tensor([[ 76,  54],
#         [200,  44],
#         [ 76,  51],
#         [214,  51],
#         [248, 112]]), 'INTERVAL 0.000 - 0.075<br>CONTAINS 99.939%': tensor([[225,  47],
#         [188,  72],
#         [255,  54],
#         [168, 124],
#         [  1,  83]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          1015, 21488, 24050,  1657,  8508])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[  7, 119],
#         [167, 112],
#         [187, 114],
#         [ 12, 121],
#         [ 66,  60]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         20230,   828, 14422, 10684, 32420])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[158,   6],
#         [  6,  60],
#         [112,  86],
#         [ 83,  60],
#         [253,  36]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         10638, 19982,  1112, 23354,  3813])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 83,  14],
#         [156,  14],
#         [  8,  88],
#         [182,  58],
#         [ 29, 101]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([20343,    18,    15,    17,     1,     0,     2,    16,    12,     9,
#             7,     8,    13,    11,    14,     4,    10,     6,     3,     5,
#         20343, 23997, 20659,  4955, 11580,   720])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 1.135': tensor([[158, 119],
#         [  0,  18],
#         [  0,  15],
#         [  0,  17],
#         [  0,   1],
#         [  0,   0],
#         [  0,   2],
#         [  0,  16],
#         [  0,  12],
#         [  0,   9],
#         [  0,   7],
#         [  0,   8],
#         [  0,  13],
#         [  0,  11],
#         [  0,  14],
#         [  0,   4],
#         [  0,  10],
#         [  0,   6],
#         [  0,   3],
#         [  0,   5]]), 'INTERVAL 0.908 - 1.135<br>CONTAINS 0.003%': tensor([[158, 119]]), 'INTERVAL 0.681 - 0.908<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.454 - 0.681<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.227 - 0.454<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.000 - 0.227<br>CONTAINS 99.997%': tensor([[187,  61],
#         [161,  51],
#         [ 38,  91],
#         [ 90,  60],
#         [  5,  80]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         21549, 26780, 25078,   631, 26822])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[168,  45],
#         [209,  28],
#         [195, 118],
#         [  4, 119],
#         [209,  70]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([20646,  4361, 22769, 27613, 10663,  6484,  3610, 19889, 13074, 11591,
#         20888, 29762, 23640, 11175, 19430, 22325,  5782, 22666, 31252, 32349,
#         20646,  4361, 22769, 11591, 20888, 27613, 19889,  3610, 18512, 30210,
#          4018, 13406, 31274])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 1.253': tensor([[161,  38],
#         [ 34,   9],
#         [177, 113],
#         [215,  93],
#         [ 83,  39],
#         [ 50,  84],
#         [ 28,  26],
#         [155,  49],
#         [102,  18],
#         [ 90,  71],
#         [163,  24],
#         [232,  66],
#         [184,  88],
#         [ 87,  39],
#         [151, 102],
#         [174,  53],
#         [ 45,  22],
#         [177,  10],
#         [244,  20],
#         [252,  93]]), 'INTERVAL 1.003 - 1.253<br>CONTAINS 0.003%': tensor([[161,  38]]), 'INTERVAL 0.752 - 1.003<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.501 - 0.752<br>CONTAINS 0.006%': tensor([[ 34,   9],
#         [177, 113]]), 'INTERVAL 0.251 - 0.501<br>CONTAINS 0.037%': tensor([[ 90,  71],
#         [163,  24],
#         [215,  93],
#         [155,  49],
#         [ 28,  26]]), 'INTERVAL 0.000 - 0.251<br>CONTAINS 99.954%': tensor([[144,  80],
#         [236,   2],
#         [ 31,  50],
#         [104,  94],
#         [244,  42]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         22298, 24675,  1786,  2380, 32528])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[174,  26],
#         [192,  99],
#         [ 13, 122],
#         [ 18,  76],
#         [254,  16]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([18449, 27962,  5571, 13770, 27967, 18420, 27165,  1337, 26317, 21855,
#          9118, 23750, 31883, 25938,  4334, 28526, 19107, 20594, 14536, 20593,
#          5571, 18449, 27962,  9118, 13770, 27165, 27967, 18420, 20596, 25275,
#         19107, 27166, 23750, 19108, 31884, 25940,  1823, 21837, 17413, 29610,
#          9462, 18074, 15395])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 1.067': tensor([[144,  17],
#         [218,  58],
#         [ 43,  67],
#         [107,  74],
#         [218,  63],
#         [143, 116],
#         [212,  29],
#         [ 10,  57],
#         [205,  77],
#         [170,  95],
#         [ 71,  30],
#         [185,  70],
#         [249,  11],
#         [202,  82],
#         [ 33, 110],
#         [222, 110],
#         [149,  35],
#         [160, 114],
#         [113,  72],
#         [160, 113]]), 'INTERVAL 0.853 - 1.067<br>CONTAINS 0.009%': tensor([[ 43,  67],
#         [144,  17],
#         [218,  58]]), 'INTERVAL 0.640 - 0.853<br>CONTAINS 0.024%': tensor([[ 71,  30],
#         [107,  74],
#         [212,  29],
#         [218,  63],
#         [143, 116]]), 'INTERVAL 0.427 - 0.640<br>CONTAINS 0.098%': tensor([[160, 116],
#         [197,  59],
#         [149,  35],
#         [212,  30],
#         [185,  70]]), 'INTERVAL 0.213 - 0.427<br>CONTAINS 0.198%': tensor([[149,  36],
#         [249,  12],
#         [202,  84],
#         [ 14,  31],
#         [170,  77]]), 'INTERVAL 0.000 - 0.213<br>CONTAINS 99.670%': tensor([[136,   5],
#         [231,  42],
#         [ 73, 118],
#         [141,  26],
#         [120,  35]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          7601, 21590, 15902, 23157, 10652])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
# ...
#         [  9,   9],
#         [ 38,  83],
#         [246,  20],
#         [157, 105]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([13137,  2329, 17235, 24730, 10862, 15290,    13,    12,     8,     9,
#            10,    11,     7,     6,     1,     0,     5,     4,     2,     3,
#         13137,  2329, 17235, 24730, 10862, 32321, 18328,  7753,  5381, 29483])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.201': tensor([[102,  81],
#         [ 18,  25],
#         [134,  83],
#         [193,  26],
#         [ 84, 110],
#         [119,  58],
#         [  0,  13],
#         [  0,  12],
#         [  0,   8],
#         [  0,   9],
#         [  0,  10],
#         [  0,  11],
#         [  0,   7],
#         [  0,   6],
#         [  0,   1],
#         [  0,   0],
#         [  0,   5],
#         [  0,   4],
#         [  0,   2],
#         [  0,   3]]), 'INTERVAL 0.161 - 0.201<br>CONTAINS 0.003%': tensor([[102,  81]]), 'INTERVAL 0.121 - 0.161<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.081 - 0.121<br>CONTAINS 0.009%': tensor([[ 18,  25],
#         [134,  83],
#         [193,  26]]), 'INTERVAL 0.040 - 0.081<br>CONTAINS 0.003%': tensor([[ 84, 110]]), 'INTERVAL 0.000 - 0.040<br>CONTAINS 99.985%': tensor([[252,  65],
#         [143,  24],
#         [ 60,  73],
#         [ 42,   5],
#         [230,  43]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([ 7693, 30483,    17,    16,     0,     1,    14,    15,    11,    10,
#             6,     7,    12,    13,     2,     3,     9,     8,     5,     4,
#          7693, 28161, 23759, 10886, 13934,  4579])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.468': tensor([[ 60,  13],
#         [238,  19],
#         [  0,  17],
#         [  0,  16],
#         [  0,   0],
#         [  0,   1],
#         [  0,  14],
#         [  0,  15],
#         [  0,  11],
#         [  0,  10],
#         [  0,   6],
#         [  0,   7],
#         [  0,  12],
#         [  0,  13],
#         [  0,   2],
#         [  0,   3],
#         [  0,   9],
#         [  0,   8],
#         [  0,   5],
#         [  0,   4]]), 'INTERVAL 0.375 - 0.468<br>CONTAINS 0.003%': tensor([[60, 13]]), 'INTERVAL 0.281 - 0.375<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.187 - 0.281<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.094 - 0.187<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.000 - 0.094<br>CONTAINS 99.997%': tensor([[220,   1],
#         [185,  79],
#         [ 85,   6],
#         [108, 110],
#         [ 35,  99]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#           604, 26179, 23219,  6004, 20539])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[  4,  92],
#         [204,  67],
#         [181,  51],
#         [ 46, 116],
#         [160,  59]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         18287,  5676, 12155,  7041, 30082])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[142, 111],
#         [ 44,  44],
#         [ 94, 123],
#         [ 55,   1],
#         [235,   2]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         18285, 21693, 24537,  8567,  4372])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[142, 109],
#         [169,  61],
#         [191,  89],
#         [ 66, 119],
#         [ 34,  20]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         29860,  9608, 25026, 12098, 26765])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[233,  36],
#         [ 75,   8],
#         [195,  66],
#         [ 94,  66],
#         [209,  13]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          3614, 24015, 18644, 25171,  8612])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 28,  30],
#         [187,  79],
#         [145,  84],
#         [196,  83],
#         [ 67,  36]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([23136, 15074, 23137, 23139, 23159, 23122, 23138, 21102, 23114, 30026,
#         23111, 23115, 15725, 14116, 21111,  1156, 23161, 21101, 23541, 15082,
#         23136, 15074, 23137, 23122, 23139, 23159, 21102, 23111, 23114, 23138,
#         30026,  1205,  6321, 20468,  9845, 27292])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 1.280': tensor([[180,  96],
#         [117,  98],
#         [180,  97],
#         [180,  99],
#         [180, 119],
#         [180,  82],
#         [180,  98],
#         [164, 110],
#         [180,  74],
#         [234,  74],
#         [180,  71],
#         [180,  75],
#         [122, 109],
#         [110,  36],
#         [164, 119],
#         [  9,   4],
#         [180, 121],
#         [164, 109],
#         [183, 117],
#         [117, 106]]), 'INTERVAL 1.024 - 1.280<br>CONTAINS 0.003%': tensor([[180,  96]]), 'INTERVAL 0.768 - 1.024<br>CONTAINS 0.006%': tensor([[117,  98],
#         [180,  97]]), 'INTERVAL 0.512 - 0.768<br>CONTAINS 0.009%': tensor([[180,  82],
#         [180,  99],
#         [180, 119]]), 'INTERVAL 0.256 - 0.512<br>CONTAINS 0.015%': tensor([[164, 110],
#         [180,  71],
#         [180,  74],
#         [180,  98],
#         [234,  74]]), 'INTERVAL 0.000 - 0.256<br>CONTAINS 99.966%': tensor([[  9,  53],
#         [ 49,  49],
#         [159, 116],
#         [ 76, 117],
#         [213,  28]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([18021, 17347, 14289,   625, 18814, 12437,    13,    12,     8,     9,
#            10,    11,     7,     6,     1,     0,     5,     4,     2,     3,
#         17347, 18021, 14289,   625,  6784, 14687,  9647,   105,  1382])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.702': tensor([[140, 101],
#         [135,  67],
#         [111,  81],
#         [  4, 113],
#         [146, 126],
#         [ 97,  21],
#         [  0,  13],
#         [  0,  12],
#         [  0,   8],
#         [  0,   9],
#         [  0,  10],
#         [  0,  11],
#         [  0,   7],
#         [  0,   6],
#         [  0,   1],
#         [  0,   0],
#         [  0,   5],
#         [  0,   4],
#         [  0,   2],
#         [  0,   3]]), 'INTERVAL 0.562 - 0.702<br>CONTAINS 0.006%': tensor([[135,  67],
#         [140, 101]]), 'INTERVAL 0.421 - 0.562<br>CONTAINS 0.003%': tensor([[111,  81]]), 'INTERVAL 0.281 - 0.421<br>CONTAINS 0.003%': tensor([[  4, 113]]), 'INTERVAL 0.140 - 0.281<br>CONTAINS 0.000%': tensor([], size=(0, 2), dtype=torch.int64), 'INTERVAL 0.000 - 0.140<br>CONTAINS 99.988%': tensor([[ 53,   0],
#         [114,  95],
#         [ 75,  47],
#         [  0, 105],
#         [ 10, 102]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         12797, 15498,  2391, 32192, 16183])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 99, 125],
#         [121,  10],
#         [ 18,  87],
#         [251,  64],
#         [126,  55]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         25049,  7396, 22853,  5850, 30002])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[195,  89],
#         [ 57, 100],
#         [178,  69],
#         [ 45,  90],
#         [234,  50]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         10114,   286, 29805,  4847, 27053])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 79,   2],
#         [  2,  30],
#         [232, 109],
#         [ 37, 111],
#         [211,  45]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         24030, 31446,  4581, 20199, 13799])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[187,  94],
#         [245,  86],
#         [ 35, 101],
#         [157, 103],
#         [107, 103]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         28495, 23066, 19777, 28653,  3127])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[222,  79],
#         [180,  26],
#         [154,  65],
#         [223, 109],
#         [ 24,  55]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         10392, 14223, 15672, 14346,  1173])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[ 81,  24],
#         [111,  15],
#         [122,  56],
#         [112,  10],
#         [  9,  21]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#         13148, 13854, 19589, 16249, 10348])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[102,  92],
#         [108,  30],
#         [153,   5],
#         [126, 121],
#         [ 80, 108]])}
# Processed batch of 256 sequences
# Original indices bold: tensor([   19,    18,    16,    17,     1,     0,     2,     3,    11,    10,
#             8,     9,    13,    12,    14,    15,     7,     6,     4,     5,
#          1109,  3623,  2171,  1427, 15299])
# Indices dict: {'TOP ACTIVATIONS<br>MAX = 0.000': tensor([[ 0, 19],
#         [ 0, 18],
#         [ 0, 16],
#         [ 0, 17],
#         [ 0,  1],
#         [ 0,  0],
#         [ 0,  2],
#         [ 0,  3],
#         [ 0, 11],
#         [ 0, 10],
#         [ 0,  8],
#         [ 0,  9],
#         [ 0, 13],
#         [ 0, 12],
#         [ 0, 14],
#         [ 0, 15],
#         [ 0,  7],
#         [ 0,  6],
#         [ 0,  4],
#         [ 0,  5]]), 'INTERVAL 0.000 - 0.000<br>CONTAINS 100.000%': tensor([[  8,  85],
#         [ 28,  39],
#         [ 16, 123],
#         [ 11,  19],
#         [119,  67]])}
# ┏━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Task ┃ Time ┃ Pct % ┃
# ┡━━━━━━╇━━━━━━╇━━━━━━━┩
# └──────┴──────┴───────┘
# Saving feature-centric vis:   0%|          | 0/256 [00:00<?, ?it/s]
# 192it [00:47,  4.06it/s]
# Output written to neuronpedia_outputs/gpt2-small_gpt2-small-hook-z-kk_blocks.5.attn.hook_z/batch-0.json

# %%
import json
import os
from typing import Any, Dict, List

import pytest

def load_json_file(file_path: str) -> Dict[str, Any]:
    with open(file_path, 'r') as f:
        return json.load(f)

# %%
output_dir = '/root/SAEDashboard/neuronpedia_outputs/gpt2-small_gpt2-small-hook-z-kk_blocks.5.attn.hook_z'
    
# Find all batch files
batch_files = [f for f in os.listdir(output_dir) if f.startswith('batch-') and f.endswith('.json')]

assert len(batch_files) > 0, "No batch files found in the output directory"

file_path = os.path.join(output_dir, batch_files[0])
batch_data = load_json_file(file_path)

# %%
batch_data["features"][0]["activations"][0].keys()
# Out:
# dict_keys(['bin_min', 'bin_max', 'bin_contains', 'tokens', 'values', 'dfa_values', 'dfa_maxValue', 'dfa_targetIndex'])

# %%
len(batch_data["features"][15]["activations"][0]['tokens'])
# Out:
# 127

# %%
seq_idx = 6

tokens = batch_data["features"][15]["activations"][seq_idx]["tokens"]
dfa_values = batch_data["features"][15]["activations"][seq_idx]["dfa_values"]
print(f" Max DFA Value Index: {batch_data['features'][15]['activations'][seq_idx]['dfa_targetIndex']}")
for token, dfa_value in zip(tokens, dfa_values):
    print(f"Token: {token}: {round(dfa_value, 4)}")
# Out:
#  Max DFA Value Index: 19
# Token: Port: 0.5154
# Token: -: -0.0036
# Token: au: -0.0009
# Token: -: -0.0012
# Token: Prince: -0.0006
# Token: ,: -0.0005
# Token:  Haiti: 0.0011
# Token:  (: -0.005
# Token: CNN: -0.0016
# Token: ): 0.0024
# Token:  --: -0.0002
# Token:  Earthquake: -0.0003
# Token:  victims: -0.0227
# Token: ,: 0.0186
# Token:  wr: 0.0609
# Token: ithing: -0.0221
# Token:  in: 0.4329
# Token:  pain: 0.5258
# Token:  and: 0.525
# Token:  grasping: 0.1648
# Token:  at: 0.0
# Token:  life: 0.0
# Token: ,: 0.0
# Token:  watched: 0.0
# Token:  doctors: 0.0
# Token:  and: 0.0
# Token:  nurses: 0.0
# Token:  walk: 0.0
# Token:  away: 0.0
# Token:  from: 0.0
# Token:  a: 0.0
# Token:  field: 0.0
# Token:  hospital: 0.0
# Token:  Friday: 0.0
# Token:  night: 0.0
# Token:  after: 0.0
# Token:  a: 0.0
# Token:  Belgian: 0.0
# Token:  medical: 0.0
# Token:  team: 0.0
# Token:  evacuated: 0.0
# Token:  the: 0.0
# Token:  area: 0.0
# Token: ,: 0.0
# Token:  saying: 0.0
# Token:  it: 0.0
# Token:  was: 0.0
# Token:  concerned: 0.0
# Token:  about: 0.0
# Token:  security: 0.0
# Token: .: 0.0
# Token:
# : 0.0
# Token:
# : 0.0
# Token: The: 0.0
# Token:  decision: 0.0
# Token:  left: 0.0
# Token:  CNN: 0.0
# Token:  Chief: 0.0
# Token:  Medical: 0.0
# Token:  Correspond: 0.0
# Token: ent: 0.0
# Token:  San: 0.0
# Token: jay: 0.0
# Token:  Gupta: 0.0
# Token:  as: 0.0
# Token:  the: 0.0
# Token:  only: 0.0
# Token:  doctor: 0.0
# Token:  at: 0.0
# Token:  the: 0.0
# Token:  hospital: 0.0
# Token:  to: 0.0
# Token:  get: 0.0
# Token:  the: 0.0
# Token:  patients: 0.0
# Token:  through: 0.0
# Token:  the: 0.0
# Token:  night: 0.0
# Token: .: 0.0
# Token:
# : 0.0
# Token:
# : 0.0
# Token: CNN: 0.0
# Token:  initially: 0.0
# Token:  reported: 0.0
# Token: ,: 0.0
# Token:  based: 0.0
# Token:  on: 0.0
# Token:  conversations: 0.0
# Token:  with: 0.0
# Token:  some: 0.0
# Token:  of: 0.0
# Token:  the: 0.0
# Token:  doctors: 0.0
# Token: ,: 0.0
# Token:  that: 0.0
# Token:  the: 0.0
# Token:  United: 0.0
# Token:  Nations: 0.0
# Token:  ordered: 0.0
# Token:  the: 0.0
# Token:  Belgian: 0.0
# Token:  First: 0.0
# Token:  Aid: 0.0
# Token:  and: 0.0
# Token:  Support: 0.0
# Token:  Team: 0.0
# Token:  to: 0.0
# Token:  evacuate: 0.0
# Token: .: 0.0
# Token:  However: 0.0
# Token: ,: 0.0
# Token:  Belgian: 0.0
# Token:  Chief: 0.0
# Token:  Coordinator: 0.0
# Token:  Ge: 0.0
# Token: ert: 0.0
# Token:  G: 0.0
# Token: ij: 0.0
# Token: s: 0.0
# Token: ,: 0.0
# Token:  a: 0.0
# Token:  doctor: 0.0
# Token:  who: 0.0
# Token:  was: 0.0
# Token:  at: 0.0
# Token:  the: 0.0
# Token:  hospital: 0.0
